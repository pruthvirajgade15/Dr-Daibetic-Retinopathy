# %% [markdown]
# # Explainable AI for Diabetic Retinopathy Detection - Research & Experiments
#
# This notebook covers:
# 1. Fundus Image Preprocessing (Ben Graham method + CLAHE)
# 2. Quality Assessment (Laplacian focus + exposure)
# 3. Transfer Learning with EfficientNet-B0 on APTOS 2019 dataset
# 4. Saliency mapping with Grad-CAM and quadrant attention

# %%
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

from src.preprocessing import ben_graham_clahe
from src.train import RetinalDataset, train_model
from src.explain import generate_gradcam_heatmap

print(f"CUDA Available: {torch.cuda.is_available()}")

# %%
# Train model on processed dataset
train_model(data_dir="../data/processed", epochs=5)
